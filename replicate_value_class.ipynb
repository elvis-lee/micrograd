# %%
class Value:
    def __init__(self, data, prev=[], operation=""):
        self.data = data
        self.grad = 0
        self._prev = prev
        self._operation = operation
        self._backward = lambda: None
    def __repr__(self):
        return f"Value(data={self.data}, grad={self.grad}), operation={self._operation}"
    def __add__(self, other):
        other = other if isinstance(other, Value) else Value(other)
        output = Value(self.data + other.data, [self, other], "+")
        def backward():
            self.grad += output.grad
            other.grad += output.grad
        output._backward = backward
        return output
    def __sub__(self, other):
        return self + (-other)
    def __mul__(self, other):
        other = other if isinstance(other, Value) else Value(other)
        output = Value(self.data * other.data, [self, other], "*")
        def backward():
            self.grad += output.grad * other.data
            other.grad += output.grad * self.data
        output._backward = backward
        return output
    def __pow__(self, k):
        output = Value(self.data ** (k), [self], "pow")
        def backward():
            self.grad += output.grad * k * self.data**(k-1)
        output._backward = backward
        return output
    def __truediv__(self, other):
        return self * other**(-1)
    def __neg__(self):
        return self * Value(-1)
    def backward(self):
        visited = set()
        sorted = []
        def topSort(node):
            if node in visited:
                return
            for prev in node._prev:
                topSort(prev)
            sorted.append(node)
            visited.add(node)
        topSort(self)
        self.grad = 1
        for node in reversed(sorted):
            node._backward()

# %%
x1 = Value(0); y1 = Value(2)
x2 = Value(1); y2 = Value(5)

# %%
w = Value(1)
b = Value (-2)

lr = 0.1

for i in range(10):
    print("##### iteration " + str(i) + "#####")
    print("==forward pass")
    L = ((x1*w+b - y1)**2 + (x2*w+b - y2)**2)/2
    print("L=" + str(L))

    print("==backward pass")
    w.grad = 0;b.grad = 0
    x1.grad = 0; y1.grad = 0; x2.grad = 0; y2.grad = 0
    L.backward()
    print(w)
    print(b)

    print("==gradient descent")
    w.data += -lr * w.grad
    b.data += -lr * b.grad
    print(w)
    print(b)
# Out:
# ##### iteration 0#####
# ==forward pass
# L=Value(data=26.0, grad=0), operation=*
# ==backward pass
# Value(data=1, grad=-6.0), operation=
# Value(data=-2, grad=-10.0), operation=
# ==gradient descent
# Value(data=1.6, grad=-6.0), operation=
# Value(data=-1.0, grad=-10.0), operation=
# ##### iteration 1#####
# ==forward pass
# L=Value(data=14.180000000000001, grad=0), operation=*
# ==backward pass
# Value(data=1.6, grad=-4.4), operation=
# Value(data=-1.0, grad=-7.4), operation=
# ==gradient descent
# Value(data=2.04, grad=-4.4), operation=
# Value(data=-0.2599999999999999, grad=-7.4), operation=
# ##### iteration 2#####
# ==forward pass
# L=Value(data=7.737999999999998, grad=0), operation=*
# ==backward pass
# Value(data=2.04, grad=-3.2199999999999998), operation=
# Value(data=-0.2599999999999999, grad=-5.4799999999999995), operation=
# ==gradient descent
# Value(data=2.362, grad=-3.2199999999999998), operation=
# Value(data=0.28800000000000003, grad=-5.4799999999999995), operation=
# ##### iteration 3#####
# ==forward pass
# L=Value(data=4.226721999999999, grad=0), operation=*
# ==backward pass
# Value(data=2.362, grad=-2.3499999999999996), operation=
# Value(data=0.28800000000000003, grad=-4.061999999999999), operation=
# ==gradient descent
# Value(data=2.597, grad=-2.3499999999999996), operation=
# Value(data=0.6941999999999999, grad=-4.061999999999999), operation=
# ##### iteration 4#####
# ==forward pass
# L=Value(data=2.3125555400000004, grad=0), operation=*
# ==backward pass
# Value(data=2.597, grad=-1.7088), operation=
# Value(data=0.6941999999999999, grad=-3.0146), operation=
# ==gradient descent
# Value(data=2.76788, grad=-1.7088), operation=
# Value(data=0.99566, grad=-3.0146), operation=
# ##### iteration 5#####
# ==forward pass
# L=Value(data=1.2687660836, grad=0), operation=*
# ==backward pass
# Value(data=2.76788, grad=-1.2364600000000001), operation=
# Value(data=0.99566, grad=-2.2408), operation=
# ==gradient descent
# Value(data=2.891526, grad=-1.2364600000000001), operation=
# Value(data=1.21974, grad=-2.2408), operation=
# ##### iteration 6#####
# ==forward pass
# L=Value(data=0.6993268951780003, grad=0), operation=*
# ==backward pass
# Value(data=2.891526, grad=-0.8887340000000004), operation=
# Value(data=1.21974, grad=-1.6689940000000003), operation=
# ==gradient descent
# Value(data=2.9803994, grad=-0.8887340000000004), operation=
# Value(data=1.3866394, grad=-1.6689940000000003), operation=
# ##### iteration 7#####
# ==forward pass
# L=Value(data=0.38842555316890026, grad=0), operation=*
# ==backward pass
# Value(data=2.9803994, grad=-0.6329612000000004), operation=
# Value(data=1.3866394, grad=-1.2463218000000005), operation=
# ==gradient descent
# Value(data=3.04369552, grad=-0.6329612000000004), operation=
# Value(data=1.51127158, grad=-1.2463218000000005), operation=
# ##### iteration 8#####
# ==forward pass
# L=Value(data=0.21845487529905325, grad=0), operation=*
# ==backward pass
# Value(data=3.04369552, grad=-0.4450329000000002), operation=
# Value(data=1.51127158, grad=-0.9337613200000001), operation=
# ==gradient descent
# Value(data=3.08819881, grad=-0.4450329000000002), operation=
# Value(data=1.604647712, grad=-0.9337613200000001), operation=
# ##### iteration 9#####
# ==forward pass
# L=Value(data=0.12532334533716571, grad=0), operation=*
# ==backward pass
# Value(data=3.08819881, grad=-0.30715347800000004), operation=
# Value(data=1.604647712, grad=-0.702505766), operation=
# ==gradient descent
# Value(data=3.1189141578000004, grad=-0.30715347800000004), operation=
# Value(data=1.6748982886000001, grad=-0.702505766), operation=
